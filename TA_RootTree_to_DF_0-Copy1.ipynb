# %%
import uproot3
import numpy as np
import pandas as pd

# %%
Dir='/nfs/kloe/einstein4/martino/'
files=Dir+'TA_Files/'

mode='VariableCone'
#mode='FixedCone'
file = uproot3.open(files+"TrackAssociator.Zprime."+mode+".root");
path=Dir+'PKL/Zprime'+mode+'/'

# %%
tree=file["analysis"]

# %%
tree.keys()
# Out:
# [b'RunNumber',
#  b'EventNumber',
#  b'Jet_eta',
#  b'Jet_phi',
#  b'Jet_pt',
#  b'Jet_E',
#  b'jet_ConeLabel',
#  b'jet_ExtendedConeLabel',
#  b'Jet_closestJetDR',
#  b'bH_eta',
#  b'bH_phi',
#  b'bH_pt',
#  b'bH_E',
#  b'bH_ptfrac',
#  b'bH_DR',
#  b'trk_eta',
#  b'trk_theta',
#  b'trk_phi',
#  b'trk_pt',
#  b'trk_E',
#  b'trk_Deta',
#  b'trk_Dphi',
#  b'trk_dr',
#  b'trk_ptfrac',
#  b'trk_pzfrac',
#  b'trk_p3fracJetE',
#  b'trk_incl_origin',
#  b'trk_excl_origin',
#  b'trk_isfromBD',
#  b'trk_isfromBoutDR',
#  b'trk_isfromtau',
#  b'trk_closestJetDR',
#  b'trk_closestJet_Deta',
#  b'trk_closestJet_Dphi',
#  b'trk_closestJet_DRtrkjet',
#  b'trk_d0',
#  b'trk_z0']

# %%
Jagged_jetPt=tree["Jet_pt"].array()
Jagged_jetEta=tree["Jet_eta"].array()
Jagged_jetPhi=tree["Jet_phi"].array()
Jagged_jetE=tree["Jet_E"].array()
Jagged_ExtendedConeLabel=tree['jet_ExtendedConeLabel'].array()
#Jagged_closestJetDR=tree['Jet_closestJetDR'].array()


Jagged_trkPt=tree['trk_pt'].array()
Jagged_trkEta=tree['trk_eta'].array()
Jagged_trkDeta=tree['trk_Deta'].array()
Jagged_trkTheta=tree['trk_theta'].array()
Jagged_trkPhi=tree['trk_phi'].array()
Jagged_trkDphi=tree['trk_Dphi'].array()
Jagged_trkE=tree['trk_E'].array()
Jagged_trkDR=tree['trk_dr'].array()
Jagged_trkPtfrac=tree['trk_ptfrac'].array()
Jagged_trkPzfrac=tree['trk_pzfrac'].array()
Jagged_trkP3fracJetE=tree['trk_p3fracJetE'].array()
Jagged_trkinclorigin=tree['trk_incl_origin'].array()
Jagged_trkexclorigin=tree['trk_excl_origin'].array()
Jagged_trkisfromBD=tree['trk_isfromBD'].array()
Jagged_trkisfromBoutDR=tree['trk_isfromBoutDR'].array()
Jagged_trkisfromtau=tree['trk_isfromtau'].array()
Jagged_trkclosestJetDR=tree['trk_closestJetDR'].array()
Jagged_trkclosestJet_Deta=tree['trk_closestJet_Deta'].array()
Jagged_trkclosestJet_Dphi=tree['trk_closestJet_Dphi'].array()
Jagged_trkclosestJet_DRtrkjet=tree['trk_closestJet_DRtrkjet'].array()
Jagged_trkd0=tree['trk_d0'].array()
Jagged_trkz0=tree['trk_z0'].array()

# %%
Jagged_bHPt=tree['bH_pt'].array()
Jagged_bHDR=tree['bH_DR'].array()
Jagged_bHPtfrac=tree['bH_ptfrac'].array()

# %%
N_evts=Jagged_jetPt.shape[0] #N of events
print(N_evts)
# Out:
# 110000

# %%
def general_dumper(ExtendConeLab):

    
    tmp_jetpt=np.array([])
    tmp_jeteta=np.array([])
    tmp_jetphi=np.array([])
    tmp_jetE=np.array([])
    tmp_closestJetDR=np.array([])


    singleB_jetPt=np.array([])
    singleB_jetEta=np.array([])
    singleB_jetPhi=np.array([])
    singleB_jetE=np.array([])
    singleB_closestJetDR=np.array([])

    tmp_trkpt=np.array([])
    tmp_trketa=np.array([])
    tmp_trkDeta=np.array([])
    tmp_trktheta=np.array([])
    tmp_trkphi=np.array([])
    tmp_trkDphi=np.array([])
    tmp_trkE=np.array([])
    tmp_trkDR=np.array([])
    tmp_trkptfrac=np.array([])
    tmp_trkpzfrac=np.array([])
    tmp_trkP3fracJetE=np.array([])
    tmp_trkinclorigin=np.array([])
    tmp_trkexclorigin=np.array([])
    tmp_trkisfromBD=np.array([])
    tmp_trkisfromBoutDR=np.array([])
    tmp_trkisfromtau=np.array([])
    tmp_trkd0=np.array([])
    tmp_trkz0=np.array([])
    tmp_trkclosestJetDR=np.array([])
    tmp_trkclosestJetDeta=np.array([])
    tmp_trkclosestJetDphi=np.array([])
    tmp_trkclosestJetDRtrkjet=np.array([])

    singleB_trkPt=np.array([])
    singleB_trkEta=np.array([])
    singleB_trkDeta=np.array([])
    singleB_trkTheta=np.array([])
    singleB_trkPhi=np.array([])
    singleB_trkDphi=np.array([])
    singleB_trkE=np.array([])
    singleB_trkDR=np.array([])
    singleB_trkPtfrac=np.array([])
    singleB_trkPzfrac=np.array([])
    singleB_trkP3fracJetE=np.array([])
    singleB_trkinclorigin=np.array([])
    singleB_trkexclorigin=np.array([])
    singleB_trkisfromBD=np.array([])
    singleB_trkisfromBoutDR=np.array([])
    singleB_trkisfromtau=np.array([])
    singleB_trkclosestJetDR=np.array([])
    singleB_trkclosestJetDeta=np.array([])
    singleB_trkclosestJetDphi=np.array([])
    singleB_trkclosestJetDRtrkjet=np.array([])
    singleB_trkd0=np.array([])
    singleB_trkz0=np.array([])

    err=0
    N=int(1*N_evts)
    N=50000
    print(N)
    
    for evt in range(0,N):
    #    print(evt)
        mask=np.where(Jagged_ExtendedConeLabel[evt]==ExtendConeLab)
        if len(mask[0])==0:
#            err=err+1
            continue

        tmp_jetpt=Jagged_jetPt[evt][mask]
        tmp_jeteta=Jagged_jetEta[evt][mask]
        tmp_jetphi=Jagged_jetPhi[evt][mask]
        tmp_jetE=Jagged_jetE[evt][mask]
    #    tmp_closestJetDR=Jagged_closestJetDR[evt][mask] 
    
        tmp_trkpt=np.array(Jagged_trkPt[evt],dtype=object)[mask]
        tmp_trkEta=np.array(Jagged_trkEta[evt],dtype=object)[mask]
        tmp_trkDeta=np.array(Jagged_trkDeta[evt],dtype=object)[mask]
        tmp_trkTheta=np.array(Jagged_trkTheta[evt],dtype=object)[mask]
        tmp_trkPhi=np.array(Jagged_trkPhi[evt],dtype=object)[mask]
        tmp_trkDphi=np.array(Jagged_trkDphi[evt],dtype=object)[mask]
        tmp_trkE=np.array(Jagged_trkE[evt],dtype=object)[mask]
        tmp_trkDR=np.array(Jagged_trkDR[evt],dtype=object)[mask]
        tmp_trkPtfrac=np.array(Jagged_trkPtfrac[evt],dtype=object)[mask] 
        tmp_trkPzfrac=np.array(Jagged_trkPzfrac[evt],dtype=object)[mask] 
        tmp_trkP3fracJetE=np.array(Jagged_trkP3fracJetE[evt],dtype=object)[mask] 
        tmp_trkinclorigin=np.array(Jagged_trkinclorigin[evt],dtype=object)[mask] 
        tmp_trkexclorigin=np.array(Jagged_trkexclorigin[evt],dtype=object)[mask] 
        tmp_trkisfromBD=np.array(Jagged_trkisfromBD[evt],dtype=object)[mask] 
        tmp_trkisfromBoutDR=np.array(Jagged_trkisfromBoutDR[evt],dtype=object)[mask] 
        tmp_trkisfromtau=np.array(Jagged_trkisfromtau[evt],dtype=object)[mask] 
        tmp_trkd0=np.array(Jagged_trkd0[evt],dtype=object)[mask] 
        tmp_trkz0=np.array(Jagged_trkz0[evt],dtype=object)[mask] 
        tmp_trkclosestJetDR=np.array(Jagged_trkclosestJetDR[evt],dtype=object)[mask] 
        tmp_trkclosestJetDeta=np.array(Jagged_trkclosestJet_Deta[evt],dtype=object)[mask] 
        tmp_trkclosestJetDphi=np.array(Jagged_trkclosestJet_Dphi[evt],dtype=object)[mask] 
        tmp_trkclosestJetDRtrkjet=np.array(Jagged_trkclosestJet_DRtrkjet[evt],dtype=object)[mask] 


#        if tmp_jetpt.size==tmp_trkpt.size:
        if tmp_jetpt.shape[0]==tmp_trkpt.shape[0]:
            singleB_jetPt=np.append(singleB_jetPt,tmp_jetpt)
            singleB_jetEta=np.append(singleB_jetEta,tmp_jeteta)
            singleB_jetPhi=np.append(singleB_jetPhi,tmp_jetphi)
            singleB_jetE=np.append(singleB_jetE,tmp_jetE)
            #singleB_closestJetDR=np.append(singleB_closestJetDR,tmp_closestJetDR)

            singleB_trkPt=np.append(singleB_trkPt,tmp_trkpt)
            singleB_trkEta=np.append(singleB_trkEta,tmp_trkEta)
            singleB_trkDeta=np.append(singleB_trkDeta,tmp_trkDeta)
            singleB_trkTheta=np.append(singleB_trkTheta,tmp_trkTheta)
            singleB_trkPhi=np.append(singleB_trkPhi,tmp_trkPhi)
            singleB_trkDphi=np.append(singleB_trkDphi,tmp_trkDphi)
            singleB_trkE=np.append(singleB_trkE,tmp_trkE)
            singleB_trkDR=np.append(singleB_trkDR,tmp_trkDR)
            singleB_trkPtfrac=np.append(singleB_trkPtfrac,tmp_trkPtfrac)
            singleB_trkPzfrac=np.append(singleB_trkPzfrac,tmp_trkPzfrac)
            singleB_trkP3fracJetE=np.append(singleB_trkP3fracJetE,tmp_trkP3fracJetE)
            singleB_trkinclorigin=np.append(singleB_trkinclorigin,tmp_trkinclorigin)
            singleB_trkexclorigin=np.append(singleB_trkexclorigin,tmp_trkexclorigin)
            singleB_trkisfromBD=np.append(singleB_trkisfromBD,tmp_trkisfromBD)
            singleB_trkisfromBoutDR=np.append(singleB_trkisfromBoutDR,tmp_trkisfromBoutDR)
            singleB_trkisfromtau=np.append(singleB_trkisfromtau,tmp_trkisfromtau)
            singleB_trkd0=np.append(singleB_trkd0,tmp_trkd0)
            singleB_trkz0=np.append(singleB_trkz0,tmp_trkz0)
            singleB_trkclosestJetDR=np.append(singleB_trkclosestJetDR,tmp_trkclosestJetDR)
            singleB_trkclosestJetDeta=np.append(singleB_trkclosestJetDeta,tmp_trkclosestJetDeta)
            singleB_trkclosestJetDphi=np.append(singleB_trkclosestJetDphi,tmp_trkclosestJetDphi)
            singleB_trkclosestJetDRtrkjet=np.append(singleB_trkclosestJetDRtrkjet,tmp_trkclosestJetDRtrkjet)

        else:
            err=err+1
            print(evt,tmp_jetpt,tmp_trkpt)

        print(format(float(evt/N),'02'),end='')
        print('\r', end='')

    print("Error fraction:",err/N)
    
    
    singleB_jet_data=np.vstack((singleB_jetPt,
                singleB_jetEta,
                singleB_jetPhi,
                singleB_jetE#,
#                singleB_closestJetDR
                           )).T

    singleBJet_df=pd.DataFrame(singleB_jet_data,columns=['pT','Eta','Phi','E'])
    
    singleB_trkPt_flatten=np.array([])
    singleB_trkEta_flatten=np.array([])
    singleB_trkDeta_flatten=np.array([])
    singleB_trkTheta_flatten=np.array([])
    singleB_trkPhi_flatten=np.array([])
    singleB_trkDphi_flatten=np.array([])
    singleB_trkE_flatten=np.array([])
    singleB_trkDR_flatten=np.array([])
    singleB_trkPtfrac_flatten=np.array([])
    singleB_trkPzfrac_flatten=np.array([])
    singleB_trkP3fracJetE_flatten=np.array([])
    singleB_trkinclorigin_flatten=np.array([])
    singleB_trkexclorigin_flatten=np.array([])
    singleB_trkisfromBD_flatten=np.array([])
    singleB_trkisfromBoutDR_flatten=np.array([])
    singleB_trkisfromtau_flatten=np.array([])
    singleB_trkclosestJetDR_flatten=np.array([])
    singleB_trkclosestJetDeta_flatten=np.array([])
    singleB_trkclosestJetDphi_flatten=np.array([])
    singleB_trkclosestJetDRtrkjet_flatten=np.array([])
    singleB_trkd0_flatten=np.array([])
    singleB_trkz0_flatten=np.array([])

    q=0
    for x in singleB_trkPt:
        singleB_trkPt_flatten=np.append(singleB_trkPt_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkEta:
        singleB_trkEta_flatten=np.append(singleB_trkEta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDeta:
        singleB_trkDeta_flatten=np.append(singleB_trkDeta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkTheta:
        singleB_trkTheta_flatten=np.append(singleB_trkTheta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPhi:
        singleB_trkPhi_flatten=np.append(singleB_trkPhi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDphi:
        singleB_trkDphi_flatten=np.append(singleB_trkDphi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkE:
        singleB_trkE_flatten=np.append(singleB_trkE_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDR:
        singleB_trkDR_flatten=np.append(singleB_trkDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPtfrac:
        singleB_trkPtfrac_flatten=np.append(singleB_trkPtfrac_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPzfrac:
        singleB_trkPzfrac_flatten=np.append(singleB_trkPzfrac_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkP3fracJetE:
        singleB_trkP3fracJetE_flatten=np.append(singleB_trkP3fracJetE_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkinclorigin:
        singleB_trkinclorigin_flatten=np.append(singleB_trkinclorigin_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkexclorigin:
        singleB_trkexclorigin_flatten=np.append(singleB_trkexclorigin_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromBD:
        singleB_trkisfromBD_flatten=np.append(singleB_trkisfromBD_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromBoutDR:
        singleB_trkisfromBoutDR_flatten=np.append(singleB_trkisfromBoutDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromtau:
        singleB_trkisfromtau_flatten=np.append(singleB_trkisfromtau_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkd0:
        singleB_trkd0_flatten=np.append(singleB_trkd0_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkz0:
        singleB_trkz0_flatten=np.append(singleB_trkz0_flatten,x)
    q=q+1
    print('done ',q,end='')
    
    for x in singleB_trkclosestJetDR:
        singleB_trkclosestJetDR_flatten=np.append(singleB_trkclosestJetDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDeta:
        singleB_trkclosestJetDeta_flatten=np.append(singleB_trkclosestJetDeta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDphi:
        singleB_trkclosestJetDphi_flatten=np.append(singleB_trkclosestJetDphi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDRtrkjet:
        singleB_trkclosestJetDRtrkjet_flatten=np.append(singleB_trkclosestJetDRtrkjet_flatten,x)
    q=q+1
    print('done ',q,end='')
    
    singleB_trk_data=np.vstack((singleB_trkPt_flatten,
                singleB_trkEta_flatten,
                singleB_trkDeta_flatten,
                singleB_trkTheta_flatten,
                singleB_trkPhi_flatten,
                singleB_trkDphi_flatten,
                singleB_trkE_flatten,
                singleB_trkDR_flatten,
                singleB_trkPtfrac_flatten,
                singleB_trkPzfrac_flatten,
                singleB_trkP3fracJetE_flatten,
                singleB_trkinclorigin_flatten,
                singleB_trkexclorigin_flatten,
                singleB_trkisfromBD_flatten,
                singleB_trkisfromBoutDR_flatten,
                singleB_trkisfromtau_flatten,            
                singleB_trkclosestJetDR_flatten,
                singleB_trkclosestJetDeta_flatten,
                singleB_trkclosestJetDphi_flatten,
                singleB_trkclosestJetDRtrkjet_flatten,
                singleB_trkd0_flatten,
                singleB_trkz0_flatten)).T

    singleBTrk_df=pd.DataFrame(singleB_trk_data,columns=['pT',
                                                         'Eta',
                                                         'Deta',
                                                         'Theta',
                                                         'Phi',
                                                         'Dphi',
                                                         'E',
                                                         'DR',
                                                         'pTfrac',
                                                         'pZfrac',
                                                         'p3fracJetE',
                                                         'incl_origin',
                                                         'excl_origin',
                                                         'isfromBD',
                                                         'isfromBoutDR',
                                                         'isfromtau',
                                                         'closestJetDR',
                                                         'closestJetDeta',
                                                         'closestJetDphi',
                                                         'closestJetDRtrkjet',
                                                         'trk_d0','trk_z0SinTheta'])
    
    return singleBJet_df,singleBTrk_df

# %%
def B_dumper(bH_ptfrac_cut):

    ExtendConeLab=5
    tmp_jetpt=np.array([])
    tmp_jeteta=np.array([])
    tmp_jetphi=np.array([])
    tmp_jetE=np.array([])
    tmp_closestJetDR=np.array([])
    tmp_bHpt=np.array([])
    tmp_bHDR=np.array([])
    tmp_bHptfrac=np.array([])


    singleB_jetPt=np.array([])
    singleB_jetEta=np.array([])
    singleB_jetPhi=np.array([])
    singleB_jetE=np.array([])
    singleB_closestJetDR=np.array([])
    singleB_bHPt=np.array([])
    singleB_bHDR=np.array([])
    singleB_bHPtfrac=np.array([])

    tmp_trkpt=np.array([])
    tmp_trketa=np.array([])
    tmp_trkDeta=np.array([])
    tmp_trktheta=np.array([])
    tmp_trkphi=np.array([])
    tmp_trkDphi=np.array([])
    tmp_trkE=np.array([])
    tmp_trkDR=np.array([])
    tmp_trkptfrac=np.array([])
    tmp_trkpzfrac=np.array([])
    tmp_trkP3fracJetE=np.array([])
    tmp_trkinclorigin=np.array([])
    tmp_trkexclorigin=np.array([])
    tmp_trkisfromBD=np.array([])
    tmp_trkisfromBoutDR=np.array([])
    tmp_trkisfromtau=np.array([])
    tmp_trkd0=np.array([])
    tmp_trkz0=np.array([])
    tmp_trkclosestJetDR=np.array([])
    tmp_trkclosestJetDeta=np.array([])
    tmp_trkclosestJetDphi=np.array([])
    tmp_trkclosestJetDRtrkjet=np.array([])

    singleB_trkPt=np.array([])
    singleB_trkEta=np.array([])
    singleB_trkDeta=np.array([])
    singleB_trkTheta=np.array([])
    singleB_trkPhi=np.array([])
    singleB_trkDphi=np.array([])
    singleB_trkE=np.array([])
    singleB_trkDR=np.array([])
    singleB_trkPtfrac=np.array([])
    singleB_trkPzfrac=np.array([])
    singleB_trkP3fracJetE=np.array([])
    singleB_trkinclorigin=np.array([])
    singleB_trkexclorigin=np.array([])
    singleB_trkisfromBD=np.array([])
    singleB_trkisfromBoutDR=np.array([])
    singleB_trkisfromtau=np.array([])
    singleB_trkclosestJetDR=np.array([])
    singleB_trkclosestJetDeta=np.array([])
    singleB_trkclosestJetDphi=np.array([])
    singleB_trkclosestJetDRtrkjet=np.array([])
    singleB_trkd0=np.array([])
    singleB_trkz0=np.array([])

    err=0
    N=int(1*N_evts)
    print(N)

    for evt in range(0,N):
        mask=np.where(Jagged_ExtendedConeLabel[evt]==ExtendConeLab)
        if len(mask[0])==0:
            continue

        var=np.array(Jagged_bHPtfrac[evt])[mask]
        
        if len(var)>=1:
            if isinstance(var[0],list):
#                err=err+1
                l=np.array([])
                for q in range(0,len(var)):
                    l=np.append(l,var[q])
                var=l
                mask2=np.where(var>bH_ptfrac_cut)[0]
#                continue
            else:
                mask2=np.where(var>bH_ptfrac_cut)[0]

        
        tmp_jetpt=Jagged_jetPt[evt][mask][mask2]
        tmp_jeteta=Jagged_jetEta[evt][mask][mask2]
        tmp_jetphi=Jagged_jetPhi[evt][mask][mask2]
        tmp_jetE=Jagged_jetE[evt][mask][mask2]
    #    tmp_closestJetDR=Jagged_closestJetDR[evt][mask][mask2]
        tmp_bHpt=np.array(Jagged_bHPt[evt],dtype=object)[mask][mask2]
        tmp_bHDR=np.array(Jagged_bHDR[evt],dtype=object)[mask][mask2]
        tmp_bHPtfrac=np.array(Jagged_bHPtfrac[evt],dtype=object)[mask][mask2]

        tmp_trkpt=np.array(Jagged_trkPt[evt],dtype=object)[mask][mask2]
        tmp_trkEta=np.array(Jagged_trkEta[evt],dtype=object)[mask][mask2]
        tmp_trkDeta=np.array(Jagged_trkDeta[evt],dtype=object)[mask][mask2]
        tmp_trkTheta=np.array(Jagged_trkTheta[evt],dtype=object)[mask][mask2]
        tmp_trkPhi=np.array(Jagged_trkPhi[evt],dtype=object)[mask][mask2]
        tmp_trkDphi=np.array(Jagged_trkDphi[evt],dtype=object)[mask][mask2]
        tmp_trkE=np.array(Jagged_trkE[evt],dtype=object)[mask][mask2]
        tmp_trkDR=np.array(Jagged_trkDR[evt],dtype=object)[mask][mask2]
        tmp_trkPtfrac=np.array(Jagged_trkPtfrac[evt],dtype=object)[mask][mask2]
        tmp_trkPzfrac=np.array(Jagged_trkPzfrac[evt],dtype=object)[mask][mask2]
        tmp_trkP3fracJetE=np.array(Jagged_trkP3fracJetE[evt],dtype=object)[mask][mask2]
        tmp_trkinclorigin=np.array(Jagged_trkinclorigin[evt],dtype=object)[mask][mask2] 
        tmp_trkexclorigin=np.array(Jagged_trkexclorigin[evt],dtype=object)[mask][mask2] 
        tmp_trkisfromBD=np.array(Jagged_trkisfromBD[evt],dtype=object)[mask][mask2]
        tmp_trkisfromBoutDR=np.array(Jagged_trkisfromBoutDR[evt],dtype=object)[mask][mask2]
        tmp_trkisfromtau=np.array(Jagged_trkisfromtau[evt],dtype=object)[mask][mask2]
        tmp_trkd0=np.array(Jagged_trkd0[evt],dtype=object)[mask][mask2]
        tmp_trkz0=np.array(Jagged_trkz0[evt],dtype=object)[mask][mask2]
        tmp_trkclosestJetDR=np.array(Jagged_trkclosestJetDR[evt],dtype=object)[mask][mask2]
        tmp_trkclosestJetDeta=np.array(Jagged_trkclosestJet_Deta[evt],dtype=object)[mask][mask2]
        tmp_trkclosestJetDphi=np.array(Jagged_trkclosestJet_Dphi[evt],dtype=object)[mask][mask2]
        tmp_trkclosestJetDRtrkjet=np.array(Jagged_trkclosestJet_DRtrkjet[evt],dtype=object)[mask][mask2]


#        if tmp_jetpt.size==tmp_trkpt.size:
        if tmp_jetpt.shape[0]==tmp_trkpt.shape[0]:
            singleB_jetPt=np.append(singleB_jetPt,tmp_jetpt)
            singleB_jetEta=np.append(singleB_jetEta,tmp_jeteta)
            singleB_jetPhi=np.append(singleB_jetPhi,tmp_jetphi)
            singleB_jetE=np.append(singleB_jetE,tmp_jetE)
            #singleB_closestJetDR=np.append(singleB_closestJetDR,tmp_closestJetDR)
            singleB_bHPt=np.append(singleB_bHPt,tmp_bHpt)
            singleB_bHDR=np.append(singleB_bHDR,tmp_bHDR)
            singleB_bHPtfrac=np.append(singleB_bHPtfrac,tmp_bHPtfrac)

            singleB_trkPt=np.append(singleB_trkPt,tmp_trkpt)
            singleB_trkEta=np.append(singleB_trkEta,tmp_trkEta)
            singleB_trkDeta=np.append(singleB_trkDeta,tmp_trkDeta)
            singleB_trkTheta=np.append(singleB_trkTheta,tmp_trkTheta)
            singleB_trkPhi=np.append(singleB_trkPhi,tmp_trkPhi)
            singleB_trkDphi=np.append(singleB_trkDphi,tmp_trkDphi)
            singleB_trkE=np.append(singleB_trkE,tmp_trkE)
            singleB_trkDR=np.append(singleB_trkDR,tmp_trkDR)
            singleB_trkPtfrac=np.append(singleB_trkPtfrac,tmp_trkPtfrac)
            singleB_trkPzfrac=np.append(singleB_trkPzfrac,tmp_trkPzfrac)
            singleB_trkP3fracJetE=np.append(singleB_trkP3fracJetE,tmp_trkP3fracJetE)
            singleB_trkinclorigin=np.append(singleB_trkinclorigin,tmp_trkinclorigin)
            singleB_trkexclorigin=np.append(singleB_trkexclorigin,tmp_trkexclorigin)
            singleB_trkisfromBD=np.append(singleB_trkisfromBD,tmp_trkisfromBD)
            singleB_trkisfromBoutDR=np.append(singleB_trkisfromBoutDR,tmp_trkisfromBoutDR)
            singleB_trkisfromtau=np.append(singleB_trkisfromtau,tmp_trkisfromtau)
            singleB_trkd0=np.append(singleB_trkd0,tmp_trkd0)
            singleB_trkz0=np.append(singleB_trkz0,tmp_trkz0)
            singleB_trkclosestJetDR=np.append(singleB_trkclosestJetDR,tmp_trkclosestJetDR)
            singleB_trkclosestJetDeta=np.append(singleB_trkclosestJetDeta,tmp_trkclosestJetDeta)
            singleB_trkclosestJetDphi=np.append(singleB_trkclosestJetDphi,tmp_trkclosestJetDphi)
            singleB_trkclosestJetDRtrkjet=np.append(singleB_trkclosestJetDRtrkjet,tmp_trkclosestJetDRtrkjet)

        else:
            err=err+1
            print(evt,tmp_jetpt.size,tmp_trkpt.size)

        print(format(float(evt/N),'02'),end='')
        print('\r', end='')

    print("Error fraction:",err/N)
    
    singleB_bH_data=np.vstack((singleB_bHPt,
                singleB_bHPtfrac,
                singleB_bHDR)).T

    singleBbH_df=pd.DataFrame(singleB_bH_data,columns=['bH_pT','bH_ptfrac','bH_DR'])
    
    singleB_jet_data=np.vstack((singleB_jetPt,
                singleB_jetEta,
                singleB_jetPhi,
                singleB_jetE#,
#                singleB_closestJetDR
                           )).T

    singleBJet_df=pd.DataFrame(singleB_jet_data,columns=['pT','Eta','Phi','E'])
    
    singleB_trkPt_flatten=np.array([])
    singleB_trkEta_flatten=np.array([])
    singleB_trkDeta_flatten=np.array([])
    singleB_trkTheta_flatten=np.array([])
    singleB_trkPhi_flatten=np.array([])
    singleB_trkDphi_flatten=np.array([])
    singleB_trkE_flatten=np.array([])
    singleB_trkDR_flatten=np.array([])
    singleB_trkPtfrac_flatten=np.array([])
    singleB_trkPzfrac_flatten=np.array([])
    singleB_trkP3fracJetE_flatten=np.array([])
    singleB_trkinclorigin_flatten=np.array([])
    singleB_trkexclorigin_flatten=np.array([])
    singleB_trkisfromBD_flatten=np.array([])
    singleB_trkisfromBoutDR_flatten=np.array([])
    singleB_trkisfromtau_flatten=np.array([])
    singleB_trkclosestJetDR_flatten=np.array([])
    singleB_trkclosestJetDeta_flatten=np.array([])
    singleB_trkclosestJetDphi_flatten=np.array([])
    singleB_trkclosestJetDRtrkjet_flatten=np.array([])
    singleB_trkd0_flatten=np.array([])
    singleB_trkz0_flatten=np.array([])

    q=0
    for x in singleB_trkPt:
        singleB_trkPt_flatten=np.append(singleB_trkPt_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkEta:
        singleB_trkEta_flatten=np.append(singleB_trkEta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDeta:
        singleB_trkDeta_flatten=np.append(singleB_trkDeta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkTheta:
        singleB_trkTheta_flatten=np.append(singleB_trkTheta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPhi:
        singleB_trkPhi_flatten=np.append(singleB_trkPhi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDphi:
        singleB_trkDphi_flatten=np.append(singleB_trkDphi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkE:
        singleB_trkE_flatten=np.append(singleB_trkE_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkDR:
        singleB_trkDR_flatten=np.append(singleB_trkDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPtfrac:
        singleB_trkPtfrac_flatten=np.append(singleB_trkPtfrac_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkPzfrac:
        singleB_trkPzfrac_flatten=np.append(singleB_trkPzfrac_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkP3fracJetE:
        singleB_trkP3fracJetE_flatten=np.append(singleB_trkP3fracJetE_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkinclorigin:
        singleB_trkinclorigin_flatten=np.append(singleB_trkinclorigin_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkexclorigin:
        singleB_trkexclorigin_flatten=np.append(singleB_trkexclorigin_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromBD:
        singleB_trkisfromBD_flatten=np.append(singleB_trkisfromBD_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromBoutDR:
        singleB_trkisfromBoutDR_flatten=np.append(singleB_trkisfromBoutDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkisfromtau:
        singleB_trkisfromtau_flatten=np.append(singleB_trkisfromtau_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkd0:
        singleB_trkd0_flatten=np.append(singleB_trkd0_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkz0:
        singleB_trkz0_flatten=np.append(singleB_trkz0_flatten,x)
    q=q+1
    print('done ',q,end='')
    
    for x in singleB_trkclosestJetDR:
        singleB_trkclosestJetDR_flatten=np.append(singleB_trkclosestJetDR_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDeta:
        singleB_trkclosestJetDeta_flatten=np.append(singleB_trkclosestJetDeta_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDphi:
        singleB_trkclosestJetDphi_flatten=np.append(singleB_trkclosestJetDphi_flatten,x)
    q=q+1
    print('done ',q,end='')
    for x in singleB_trkclosestJetDRtrkjet:
        singleB_trkclosestJetDRtrkjet_flatten=np.append(singleB_trkclosestJetDRtrkjet_flatten,x)
    q=q+1
    print('done ',q,end='')
    
    singleB_trk_data=np.vstack((singleB_trkPt_flatten,
                singleB_trkEta_flatten,
                singleB_trkDeta_flatten,
                singleB_trkTheta_flatten,
                singleB_trkPhi_flatten,
                singleB_trkDphi_flatten,
                singleB_trkE_flatten,
                singleB_trkDR_flatten,
                singleB_trkPtfrac_flatten,
                singleB_trkPzfrac_flatten,
                singleB_trkP3fracJetE_flatten,
                singleB_trkinclorigin_flatten,
                singleB_trkexclorigin_flatten,
                singleB_trkisfromBD_flatten,
                singleB_trkisfromBoutDR_flatten,
                singleB_trkisfromtau_flatten,            
                singleB_trkclosestJetDR_flatten,
                singleB_trkclosestJetDeta_flatten,
                singleB_trkclosestJetDphi_flatten,
                singleB_trkclosestJetDRtrkjet_flatten,
                singleB_trkd0_flatten,
                singleB_trkz0_flatten)).T

    singleBTrk_df=pd.DataFrame(singleB_trk_data,columns=['pT',
                                                         'Eta',
                                                         'Deta',
                                                         'Theta',
                                                         'Phi',
                                                         'Dphi',
                                                         'E',
                                                         'DR',
                                                         'pTfrac',
                                                         'pZfrac',
                                                         'p3fracJetE',
                                                         'incl_origin',
                                                         'excl_origin',
                                                         'isfromBD',
                                                         'isfromBoutDR',
                                                         'isfromtau',
                                                         'closestJetDR',
                                                         'closestJetDeta',
                                                         'closestJetDphi',
                                                         'closestJetDRtrkjet',
                                                         'trk_d0','trk_z0SinTheta'])
    
    return singleBJet_df,singleBTrk_df,singleBbH_df

# %%
path
# Out:
# '/nfs/kloe/einstein4/martino/PKL/ZprimeVariableCone/'

# %%
# !ls -l /nfs/kloe/einstein4/martino/PKL/ZprimeVariableCone/
# Out:
# total 1229152
# -rw-rw----+ 1 centonze gruppo1   3640404 Jul 22 13:36 lightJet_df.csv
# -rw-rw----+ 1 centonze gruppo1 339704223 Jul 22 13:36 lightTrk_df.csv
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 22 13:39 mixedJet_oldcut
# -rw-rw----+ 1 centonze gruppo1   2201560 Jul 20 13:06 singleBbH_0.2_df.csv
# -rw-rw----+ 1 centonze gruppo1   4311681 Jul 20 13:06 singleBJet_0.2_df.csv
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 22 13:11 singleBJetcut_oldcut
# -rw-rw----+ 1 centonze gruppo1   4435310 Jul 20 17:32 singleBJet_df.csv
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 20 18:03 singleBJetisfromBDinDRcone_notaus
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 20 18:31 singleBJetisfromBDinDRcone_notaus_extendedvars
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 20 18:02 singleBJetnocut
# drwxrwx---+ 2 centonze gruppo1      4096 Jul 20 18:29 singleBJetnocut_extendedvars
# -rw-rw----+ 1 centonze gruppo1 442660989 Jul 20 13:07 singleBTrk_0.2_df.csv
# ...

# %%
oneBJet_df_m,oneBTrk_df_m=general_dumper(5)
# Out:
# 110000
# Error fraction: 0.0464
# done  1done  2done  3done  4done  5done  6done  7done  8done  9done  10done  11done  12done  13done  14done  15done  16done  17done  18done  19done  20done  21done  22

# %%
oneBJet_df_m.to_csv(path+'singleBJet_df.csv', index=False)
oneBTrk_df_m.to_csv(path+'singleBTrk_df.csv', index=False)

# %%
bH_ptfrac_cut=0.2
singleBJet_df,singleBTrk_df,singleBbH_df=B_dumper(bH_ptfrac_cut)
# Out:
# 110000
# Error fraction: 0.0464
# done  1done  2done  3done  4done  5done  6done  7done  8done  9done  10done  11done  12done  13done  14done  15done  16done  17done  18done  19done  20done  21done  22

# %%
#singleBbH_df.to_csv('../PKL/Zprime'+mode+'/singleBbH_'+str(bH_ptfrac_cut)+'_df.csv', index=False)
#singleBJet_df.to_csv('../PKL/Zprime'+mode+'/singleBJet_'+str(bH_ptfrac_cut)+'_df.csv', index=False)
#singleBTrk_df.to_csv('../PKL/Zprime'+mode+'/singleBTrk_'+str(bH_ptfrac_cut)+'_df.csv', index=False)

singleBbH_df.to_csv(path+'singleBbH_'+str(bH_ptfrac_cut)+'_df.csv', index=False)
singleBJet_df.to_csv(path+'singleBJet_'+str(bH_ptfrac_cut)+'_df.csv', index=False)
singleBTrk_df.to_csv(path+'singleBTrk_'+str(bH_ptfrac_cut)+'_df.csv', index=False)

# %%
lightJet_df,lightTrk_df=general_dumper(0)
# Out:
# 50000
# Error fraction: 0.0
# done  1done  2done  3done  4done  5done  6done  7done  8done  9done  10done  11done  12done  13done  14done  15done  16done  17done  18done  19done  20done  21done  22

# %%
lightJet_df.to_csv(path+'lightJet_df.csv', index=False)
lightTrk_df.to_csv(path+'lightTrk_df.csv', index=False)
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
oneCJet_df,oneCTrk_df=general_dumper(4)
# Out:
# 10000
# Error fraction: 0.0
# done  1done  2done  3done  4done  5done  6done  7done  8done  9done  10done  11done  12done  13done  14done  15done  16done  17done  18done  19done  20done  21done  22

# %%
oneCJet_df.to_csv(Dir+'singleCJet_df.csv', index=False)
oneCTrk_df.to_csv(Dir+'signleCTrk_df.csv', index=False)
